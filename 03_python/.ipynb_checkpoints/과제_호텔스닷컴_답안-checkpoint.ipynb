# %% [markdown]
# # JSON 데이터 언패킹 실습 과제 (호텔스 닷컴 리뷰 데이터 정리)

# %% [markdown]
# # 추출 항목
# 1) 호텔 정보(호텥 1개당 1행)
# 2) 리뷰 정보(리뷰 1개당 1행)

# %% [markdown]
# # 1. 데이터 구조 확인
# * 최상단이 list인지?
# * 각 원소가 dict인지?
# * 'data' -> 'body' 아래에 무엇이 있는지?

# %% [markdown]
# ## (답안)
# * 최상단:
# * 각 원소:
# * data -> body:

# %% [markdown]
# # 2. JSON 경로
# * 호텔ID
# * 리뷰 목록(호텔마다 어러 개)

# %% [markdown]
# ### 호텔 ID

# %%
data['data']['body']['pdpHeader']['hotelId']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data['data']['body']['pdpHeader']['hotelId']
#
# NameError: name 'data' is not defined

# %% [markdown]
# ### 리뷰 목록(호텔마다 여러 개)

# %%
data['data']['body']['reviewContrent']['reviews']['hermes']['groups'][0]['items']

# %% [markdown]
# # 3. 문제 1)호텔 정보 DataFrame 만들기
# 각 호텔(= `for hotel in data`)에 대해 아래 컬럼을 추출하여 `hotel_info_df`를 만드세요.
#
# - 컬럼:
# `hotel_id, hotel_name, hotel_grade, n_reviews, avg_rating, cleanliness, service, comfort, condition, neighbourhood, region, locality`
#
# > ⚠️ `ratingAspects`에 일부 키가 없으면 0.0을 사용하세요.
# > ⚠️ `region`이 없으면 `locality`로 대체하세요.

# %%
import json
import pandas as pd

# %%
with open("../../0_data/hotels_korea_reviews_text.JSON", encoding="utf-8") as file:
    temp = file.read()
    data = json.loads(temp)

# %%
# 일부 구조 확인
data[0].keys()
# Out:
# dict_keys(['data'])

# %%
# hotel_id
hotel_id = data[0]['data']['body']['pdpHeader']['hotelId']

# hotel_name
hotel_name = data[0]['data']['body']['propertyDescription']['name']

# hotel_grade
hotel_grade = data[0]['data']['body']['propertyDescription']['starRating']

# n_reviews 리뷰수
n_reviews = data[0]['data']['body']['reviewContent']['overall']['totalCount']

# 평점 avg_rating
avg_rating = data[0]['data']['body']['reviewContent']['overall']['rating']

# 세부평점 cleanliness
cleanliness = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['cleanliness']

# 세부평점 service
service = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['service']

# 세부평점 comfort
comfort = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['comfort']

# 세부평점 condition
condition = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['condition']

# 세부평점 neighbourhood
neighbourhood = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['neighbourhood']

# 지역 region
region = data[0]['data']['body']['propertyDescription']['address']

# 지역 locality
locality = data[0]['data']['body']['propertyDescription']['locality']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 8
#       5 hotel_name = data[0]['data']['body']['propertyDescription']['name']
#       7 # hotel_grade
# ----> 8 hotel_grade = data[0]['data']['body']['propertyDescription']['srarRating']
#      10 # n_reviews 리뷰수
#      11 n_reviews = data[0]['data']['body']['reviewContent']['overall']['totalCount']
#
# KeyError: 'srarRating'

# %% [markdown]
# * 인덱스 번호가 있으면? 반복문을 사용해야 한다.

# %%
for hotel in data:
    # hotel_id
    hotel_id = data[0]['data']['body']['pdpHeader']['hotelId']

    # hotel_name
    hotel_name = data[0]['data']['body']['propertyDescription']['name']

    # hotel_grade
    hotel_grade = data[0]['data']['body']['propertyDescription']['srarRating']

    # n_reviews 리뷰수
    n_reviews = data[0]['data']['body']['reviewContent']['overall']['totalCount']

    # 평점 avg_rating
    avg_rating = data[0]['data']['body']['reviewContent']['overall']['rating']

    # 세부평점 cleanliness
    cleanliness = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['cleanliness']

    # 세부평점 service
    service = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['service']

    # 세부평점 comfort
    comfort = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['comfort']

    # 세부평점 condition
    condition = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['condition']

    # 세부평점 neighbourhood
    neighbourhood = data[0]['data']['body']['reviewContent']['overall']['ratingAspects']['neighbourhood']

    # 지역 region
    region = data[0]['data']['body']['propertyDescription']['address']

    # 지역 locality
    locality = data[0]['data']['body']['propertyDescription']['locality']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 9
#       6 hotel_name = data[0]['data']['body']['propertyDescription']['name']
#       8 # hotel_grade
# ----> 9 hotel_grade = data[0]['data']['body']['propertyDescription']['srarRating']
#      11 # n_reviews 리뷰수
#      12 n_reviews = data[0]['data']['body']['reviewContent']['overall']['totalCount']
#
# KeyError: 'srarRating'

# %%
for hotel in data:
    # hotel_id
    hotel_id = hotel['data']['body']['pdpHeader']['hotelId']

    # hotel_name
    hotel_name = hotel['data']['body']['propertyDescription']['name']

    # hotel_grade
    hotel_grade = hotel['data']['body']['propertyDescription']['srarRating']

    # n_reviews 리뷰수
    n_reviews = hotel['data']['body']['reviewContent']['overall']['totalCount']

    # 평점 avg_rating
    avg_rating = hotel['data']['body']['reviewContent']['overall']['rating']

    # 세부평점 cleanliness
    cleanliness = hotel['data']['body']['reviewContent']['overall']['ratingAspects']['cleanliness']

    # 세부평점 service
    service = hotel['data']['body']['reviewContent']['overall']['ratingAspects']['service']

    # 세부평점 comfort
    comfort = hotel['data']['body']['reviewContent']['overall']['ratingAspects']['comfort']

    # 세부평점 condition
    condition = hotel['data']['body']['reviewContent']['overall']['ratingAspects']['condition']

    # 세부평점 neighbourhood
    neighbourhood = hotel['data']['body']['reviewContent']['overall']['ratingAspects']['neighbourhood']

    # 지역 region
    region = hotel['data']['body']['propertyDescription']['address']

    # 지역 locality
    locality = hotel['data']['body']['propertyDescription']['locality']
    print(hotel_id,hotel_name,hotel_grade,n_reviews,avg_rating,cleanliness,service,comfort,condition,neighbourhood,region,locality)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 9
#       6 hotel_name = hotel['data']['body']['propertyDescription']['name']
#       8 # hotel_grade
# ----> 9 hotel_grade = hotel['data']['body']['propertyDescription']['srarRating']
#      11 # n_reviews 리뷰수
#      12 n_reviews = hotel['data']['body']['reviewContent']['overall']['totalCount']
#
# KeyError: 'srarRating'

# %% [markdown]
# * data의 9번 comfort 에러 > comfort 키가 빠져있다.

# %%
for hotel in data:
    # hotel_id
    hotel_id = hotel['data']['body']['pdpHeader']['hotelId']

    # hotel_name
    hotel_name = hotel['data']['body']['propertyDescription']['name']

    # hotel_grade
    hotel_grade = hotel['data']['body']['propertyDescription']['srarRating']

    # n_reviews 리뷰수
    n_reviews = hotel['data']['body']['reviewContent']['overall']['totalCount']

    # 평점 avg_rating
    avg_rating = hotel['data']['body']['reviewContent']['overall']['rating']

    # 세부평점 cleanliness
    cleanliness = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('cleanliness', 0.0))

    # 세부평점 service
    service = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('service', 0.0))

    # 세부평점 comfort
    comfort = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('comfort', 0.0))

    # 세부평점 condition
    condition = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('condition',0.0))

    # 세부평점 neighbourhood
    neighbourhood = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get(neighbourhood',0.0))

    # 지역 region
    region = hotel['data']['body']['propertyDescription']['address']

    # 지역 locality
    locality = hotel['data']['body']['propertyDescription']['locality']
    print(hotel_id,hotel_name,hotel_grade,n_reviews,avg_rating,cleanliness,service,comfort,condition,neighbourhood,region,locality)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 for hotel in data:
#       2     # hotel_id
# ----> 3     hotel_id = hotel['data']['body']['pdpHeader']['hotelId']
#       5     # hotel_name
#       6     hotel_name = hotel['data']['body']['propertyDescription']['name']
#
# TypeError: string indices must be integers

# %%
hotel_info ={}
for hotel in data:
    # hotel_id
    hotel_id = hotel['data']['body']['pdpHeader']['hotelId']

    # hotel_name
    hotel_name = hotel['data']['body']['propertyDescription']['name']

    # hotel_grade
    hotel_grade = hotel['data']['body']['propertyDescription']['srarRating']

    # n_reviews 리뷰수
    n_reviews = hotel['data']['body']['reviewContent']['overall']['totalCount']

    # 평점 avg_rating
    avg_rating = hotel['data']['body']['reviewContent']['overall']['rating']

    # 세부평점 cleanliness
    cleanliness = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('cleanliness', 0.0))

    # 세부평점 service
    service = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('service', 0.0))

    # 세부평점 comfort
    comfort = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('comfort', 0.0))

    # 세부평점 condition
    condition = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('condition',0.0))

    # 세부평점 neighbourhood
    neighbourhood = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get(neighbourhood',0.0))

    # 지역 region
    region = hotel['data']['body']['propertyDescription']['address']

    # 지역 locality
    locality = hotel['data']['body']['propertyDescription']['locality']
    keys = ("hotel_id","hotel_name","hotel_grade","n_reviews","avg_rating","cleanliness","service","comfort","condition","neighbourhood","region","locality")
    values = (hotel_id,hotel_name,hotel_grade,n_reviews,avg_rating,cleanliness,service,comfort,condition,neighbourhood,region,locality)
    for key, value in zip(key, values):
        hotel_info.setdefault(key,[]).append(value)
hotel_info
hotel_info_df = pd.DataFrame(hotel_info)
hotel_info_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 for hotel in data:
#       2     # hotel_id
# ----> 3     hotel_id = hotel['data']['body']['pdpHeader']['hotelId']
#       5     # hotel_name
#       6     hotel_name = hotel['data']['body']['propertyDescription']['name']
#
# TypeError: string indices must be integers

# %% [markdown]
# * region 키 에러 발생 > region 없으면 locality로 대체

# %%
hotel_info ={}
for hotel in data:
    # hotel_id
    hotel_id = hotel['data']['body']['pdpHeader']['hotelId']

    # hotel_name
    hotel_name = hotel['data']['body']['propertyDescription']['name']

    # hotel_grade
    hotel_grade = hotel['data']['body']['propertyDescription']['srarRating']

    # n_reviews 리뷰수
    n_reviews = hotel['data']['body']['reviewContent']['overall']['totalCount']

    # 평점 avg_rating
    avg_rating = hotel['data']['body']['reviewContent']['overall']['rating']

    # 세부평점 cleanliness
    cleanliness = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('cleanliness', 0.0))

    # 세부평점 service
    service = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('service', 0.0))

    # 세부평점 comfort
    comfort = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('comfort', 0.0))

    # 세부평점 condition
    condition = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('condition',0.0))

    # 세부평점 neighbourhood
    neighbourhood = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get(neighbourhood',0.0))
    
    # 지역 locality
    locality = hotel['data']['body']['propertyDescription']['locality']
                                                                                                 
    # 지역 region
    region = hotel['data']['body']['propertyDescription']['address'].get('region', 'locality')

    
    keys = ("hotel_id","hotel_name","hotel_grade","n_reviews","avg_rating","cleanliness","service","comfort","condition","neighbourhood","region","locality")
    values = (hotel_id,hotel_name,hotel_grade,n_reviews,avg_rating,cleanliness,service,comfort,condition,neighbourhood,region,locality)
    for key, value in zip(key, values):
        hotel_info.setdefault(key,[]).append(value)
hotel_info
hotel_info_df = pd.DataFrame(hotel_info)
hotel_info_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 for hotel in data:
#       2     # hotel_id
# ----> 3     hotel_id = hotel['data']['body']['pdpHeader']['hotelId']
#       5     # hotel_name
#       6     hotel_name = hotel['data']['body']['propertyDescription']['name']
#
# TypeError: string indices must be integers

# %% [markdown]
# * 중복된 정보 발생
#     - enumerate() > 인덱스를 뽑는다.

# %%
hotel_info ={}
for hotel in enumerate(data):
    # hotel_id
    hotel_id = hotel['data']['body']['pdpHeader']['hotelId']

    # hotel_name
    hotel_name = hotel['data']['body']['propertyDescription']['name']

    # hotel_grade
    hotel_grade = hotel['data']['body']['propertyDescription']['srarRating']

    # n_reviews 리뷰수
    n_reviews = hotel['data']['body']['reviewContent']['overall']['totalCount']

    # 평점 avg_rating
    avg_rating = hotel['data']['body']['reviewContent']['overall']['rating']

    # 세부평점 cleanliness
    cleanliness = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('cleanliness', 0.0))

    # 세부평점 service
    service = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('service', 0.0))

    # 세부평점 comfort
    comfort = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('comfort', 0.0))

    # 세부평점 condition
    condition = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('condition',0.0))

    # 세부평점 neighbourhood
    neighbourhood = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get(neighbourhood',0.0))
    
    # 지역 locality
    locality = hotel['data']['body']['propertyDescription']['locality']
                                                                                                 
    # 지역 region
    region = hotel['data']['body']['propertyDescription']['address'].get('region', 'locality')

    
    keys = ("hotel_id","hotel_name","hotel_grade","n_reviews","avg_rating","cleanliness","service","comfort","condition","neighbourhood","region","locality")
    values = (hotel_id,hotel_name,hotel_grade,n_reviews,avg_rating,cleanliness,service,comfort,condition,neighbourhood,region,locality)
                                                                                                 
    for key, value in zip(key, values):
        if idx > 0 and key == "hotel_id":
            if key == "hotel_id": # 0번째가 아닌 것 부터 처리
                 if value in hotel_info[key]
                    break #continute가 되면 계속 수집? 된다.?
        hotel_info.setdefault(key,[]).append(value)

hotel_info_df = pd.DataFrame(hotel_info)
hotel_info_df
# Out:
#   Cell In[15], line 31
#     neighbourhood = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get(neighbourhood',0.0))
#                                                                                                               ^
# SyntaxError: unterminated string literal (detected at line 31)

# %%
len(hotel_info['hotel_id']) # id와 name의 길이가 다르다. 이유는 id만 걸러졌던 것.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 len(hotel_info['hotel_id']) # id와 name의 길이가 다르다. 이유는 id만 걸러졌던 것.
#
# NameError: name 'hotel_info' is not defined

# %%
len(hotel_info['hotel_name'])

# %%
# enumerate 대신 num 사용 방법
num = 0
hotel_info ={}
for hotel in enumerate(data):
    # hotel_id
    hotel_id = hotel['data']['body']['pdpHeader']['hotelId']

    # hotel_name
    hotel_name = hotel['data']['body']['propertyDescription']['name']

    # hotel_grade
    hotel_grade = hotel['data']['body']['propertyDescription']['srarRating']

    # n_reviews 리뷰수
    n_reviews = hotel['data']['body']['reviewContent']['overall']['totalCount']

    # 평점 avg_rating
    avg_rating = hotel['data']['body']['reviewContent']['overall']['rating']

    # 세부평점 cleanliness
    cleanliness = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('cleanliness', 0.0))

    # 세부평점 service
    service = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('service', 0.0))

    # 세부평점 comfort
    comfort = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('comfort', 0.0))

    # 세부평점 condition
    condition = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get('condition',0.0))

    # 세부평점 neighbourhood
    neighbourhood = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get(neighbourhood',0.0))
    
    # 지역 locality
    locality = hotel['data']['body']['propertyDescription']['locality']
                                                                                                 
    # 지역 region
    region = hotel['data']['body']['propertyDescription']['address'].get('region', 'locality')

    
    keys = ("hotel_id","hotel_name","hotel_grade","n_reviews","avg_rating","cleanliness","service","comfort","condition","neighbourhood","region","locality")
    values = (hotel_id,hotel_name,hotel_grade,n_reviews,avg_rating,cleanliness,service,comfort,condition,neighbourhood,region,locality)
                                                                                                 
    for key, value in zip(key, values):
        if idx > 0 and key == "hotel_id":
            if num == "hotel_id": # 0번째가 아닌 것 부터 처리
                 if value in hotel_info[key]
                    break #continute가 되면 계속 수집? 된다.?
        hotel_info.setdefault(key,[]).append(value)

    num += 1
                                                                                                 
hotel_info_df = pd.DataFrame(hotel_info)
hotel_info_df
# Out:
#   Cell In[15], line 31
#     neighbourhood = float(hotel['data']['body']['reviewContent']['overall']['ratingAspects'].get(neighbourhood',0.0))
#                                                                                                               ^
# SyntaxError: unterminated string literal (detected at line 31)

# %% [markdown]
# ## 3-1. 호텔 정보 CSV 저장
# * 파일명: `호텔정보.csv`
# * 인덱스 저장하지 않기(`index=False`)

# %%
hotel_info_df.to_csv("./data/호텔정보.csv", index=Fales)

# %% [markdown]
# # 문제 2)리뷰 정보 DataFrame 만들기
# 각 호텔에서 리뷰 목록을 찾아 **모든 리뷰를 하나로 합친 DataFrame**을 만들고, `hotel_id`를 함께 저장하세요.
#
# - 컬럼:
# `hotel_id, reviewDate, itineraryId, tripType, rating, description`
#
# > ⚠️ 리뷰 목록이 없을 수도 있으니 예외 처리를 고려하세요(예: `.get()` 또는 `try/except`).

# %%
# hotel_id
hotel_id = hotel['data']['body']['pdpHeader']['hotelId']
hotel_id

# %%
# 사용자리뷰 리스트
user_reviews = {}
for idx, hotel in enumerate(data):
    print(f"{idx}/{len(data)-1} 수집중  ", end="wr")
    if len(hotel['data']['body']['reviewContent']['reviews']['hermes']['groups'][0]) != 0:
        reviews = hotel['data']['body']['reviewContent']['reviews']['hermes']['groups'][0]['items']
        for idx2, review in enumerate(reviews):
            # hotel_id
            hotel_id = hotel['data']['body']['pdpHeader']['hotelId']
            # reviewDate
            reviewDate = review['reviewDate']
            # itineraryId
            itineraryId = review['itineraryId']
            # tripType
            tripType = review['tripType']
            # rating
            rating = review['rating']
            # description
            description = re.sub("[^가-힣a-zA-Z0-9]"," ",review['description']).replace("\n", " ").replace(" ", "").strip()

            keys = ("hotel_id","reviewDate","itineraryId","tripType","rating","description")
            valuew = (hotel_id,reviewDate,itineraryId,tripType,rating,description)

            for key, value in zip(keys, values):
                user_reviews.setdefault(key, []).append(value)
user_reviews_df = pd.DataFrame(user_reviews)
user_reviews_df
# Out:
# 0/9026 수집중  wr
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 19
#      17 rating = review['rating']
#      18 # description
# ---> 19 description = re.sub("[^가-힣a-zA-Z0-9]"," ",review['description']).replace("\n", " ").replace(" ", "").strip()
#      21 keys = ("hotel_id","reviewDate","itineraryId","tripType","rating","description")
#      22 valuew = (hotel_id,reviewDate,itineraryId,tripType,rating,description)
#
# NameError: name 're' is not defined

# %% [markdown]
# ## 4-1. 리뷰 CSV 저장
# * 파일명: `호텔스닷컴리뷰.csv`
# * 인덱스 저장하지 않기(`index=False`)

# %%
user_reviews_df.to_csv("./호텔스닷컴리뷰.csv", index=False)

# %% [markdown]
# # (과제)두 개로 나누지 말고 한 셀에서 저장할 수 있도록 합쳐보자.
