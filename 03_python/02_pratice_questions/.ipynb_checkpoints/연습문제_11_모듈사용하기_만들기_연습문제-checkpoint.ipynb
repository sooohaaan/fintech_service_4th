# %% [markdown]
# # datatime 모듈

# %% [markdown]
# ### 1번 문제

# %% [markdown]
# ### 2번 문제

# %% [markdown]
# ### 3번 문제

# %% [markdown]
# ### 4번 문제

# %% [markdown]
# ### 5번 문제

# %% [markdown]
# ### 6번 문제

# %% [markdown]
# ### 7번 문제

# %% [markdown]
# ### 8번 문제

# %% [markdown]
# ### 9번 문제

# %% [markdown]
# ### 10번 문제

# %% [markdown]
# # os 모듈

# %% [markdown]
# ### 11번 문제

# %% [markdown]
# ### 12번 문제

# %% [markdown]
# ### 13번 문제

# %% [markdown]
# ### 14번 문제

# %% [markdown]
# ### 15번 문제

# %% [markdown]
# ### 16번 문제

# %% [markdown]
# ### 17번 문제

# %% [markdown]
# ### 18번 문제

# %% [markdown]
# ### 19번 문제

# %% [markdown]
# ### 20번 문제

# %% [markdown]
# ### 21번 문제

# %% [markdown]
# ### 22번 문제

# %% [markdown]
# ### 23번 문제

# %% [markdown]
# ### 24번 문제

# %% [markdown]
# ### 25번 문제

# %% [markdown]
# ### 26번 문제

# %% [markdown]
# ### 27번 문제

# %% [markdown]
# ### 28번 문제

# %% [markdown]
# ### 29번 문제

# %% [markdown]
# ### 30번 문제

# %% [markdown]
# # 사용자 정의 모듈(myfunc)

# %% [markdown]
# ### 31번 문제

# %% [markdown]
# ### 32번 문제

# %% [markdown]
# ### 33번 문제

# %% [markdown]
# ### 34번 문제

# %% [markdown]
# ### 35번 문제

# %% [markdown]
# ### 36번 문제

# %% [markdown]
# ### 37번 문제

# %% [markdown]
# ### 38번 문제

# %% [markdown]
# ### 39번 문제

# %% [markdown]
# ### 40번 문제
