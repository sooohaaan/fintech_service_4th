# %% [markdown]
# # 연산자의 종류
# * 산술, 할당, 비교, 논리, 식별, 멤버

# %% [markdown]
# # 산술연산자 +, -, *, /, %, //, **

# %%
a = 10
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335

# %% [markdown]
# % 는 나머지를 구하는 연산자 (%2 로 0이면 짝수 1이면 홀수)

# %%
print(a % b)
# Out:
# 1

# %%
print(10 % 2)
# Out:
# 0

# %%
print(11 % 2)
# Out:
# 1

# %%
print(357 % 2)
# Out:
# 1

# %% [markdown]
# %로 배수 구하기

# %%
# 3의 배수
9 % 3
# Out:
# 0

# %%
12 % 3
# Out:
# 0

# %%
# 7의 배수
49 % 7
# Out:
# 0

# %%
# 1-100까지 숫자중에서 7의 배수만 출력하세요.
for i in range(1, 101):
    if i % 7 == 0:
        print(i, end = " ")
# Out:
# 7 14 21 28 35 42 49 56 63 70 77 84 91 98

# %% [markdown]
# // 몫 을 구하는 연산자

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %% [markdown]
# ** 제곱

# %%
3 ** 2
# Out:
# 9

# %%
2 ** 2
# Out:
# 4

# %% [markdown]
# # 할당연산자
# * =, +=, -=, *=, /=, %=

# %%
a = 10

# %%
a = a + 3
a
# Out:
# 13

# %%
# a = a + 3
a += 3
a
# Out:
# 16

# %%
# a = a - 3
a -= 3
a
# Out:
# 13

# %%
a *= 2
a
# Out:
# 26

# %%
a /= 3
a
# Out:
# 8.666666666666666

# %%
a %= 2
a
# Out:
# 0.6666666666666661

# %%
a **= 2
a
# Out:
# 0.44444444444444364

# %% [markdown]
# # 비교연산자
# * 같다 ==
# * 다르다 !=
# * 초과 >
# * 미만 <
# * 이상 >=
# * 이하 <=

# %%
a = 3
b = 3.0
c = 5
d = "Python"
e = "python"
f = True
g = False

# %% [markdown]
# * == 같으면 True, 다르면 False

# %%
a == b
# Out:
# True

# %%
a == c
# Out:
# False

# %%
d == e
# Out:
# False

# %% [markdown]
# * != 다르면 True, 같으면 False

# %%
# 3, 3.0
a != b
# Out:
# False

# %%
# 3, 5
a != 5
# Out:
# True

# %%
# 3, 3.0
a > b
# Out:
# False

# %%
a >= b
# Out:
# True

# %% [markdown]
# # 논리 연산자
# * and, or, not

# %% [markdown]
# * and는 두 값이 모두 참이어야 참

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# or 두 값중 하나라도 참이면 참, 두 값 모두가 거짓이어야 거짓

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# not 값을 반대로 뒤집음 True=>False, False => True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# * and, or, not의 우선순위
# * not, and, or순으로 판단

# %%
# False and False 
# False or True
# True
not True and False or not False
# Out:
# True

# %%
# True and True
10 == 10 and 10 != 5
# Out:
# True

# %% [markdown]
# # 식별연산자
# * is, is not (object, data type)이 같은지 비교

# %%
print(a, b)
# Out:
# 3 3.0

# %%
a == b
# Out:
# True

# %%
# 정수 & 실수
a is b
# Out:
# False

# %%
d = 3

# %%
a is d
# Out:
# True

# %%
a is not b
# Out:
# True

# %% [markdown]
# # 멤버연산자
# * in , not in

# %%
mem = [1,2,3,4,5]

# %%
3 in mem
# Out:
# True

# %%
10 in mem
# Out:
# False

# %%
10 not in mem
# Out:
# True

# %%
3 not in mem
# Out:
# False
