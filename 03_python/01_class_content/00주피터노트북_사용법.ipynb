# %% [markdown]
# # 주피터 노트북 사용법 \<h1>
# * 하위 목록1
#     * 하위 목록2
# ## 주피터 노트북 사용법 \<h2>
# ### 주피터 노트북 사용법\<h3>
# #### 주피터 노트북 사용법 \<h4>
# ##### 주피터 노트북 사용법 \<h5>
# ###### 주피터 노트북 사용법 \<h6>

# %%
a + b
# Out:
# 30

# %%
b = 20

# %%
a = 10

# %%
a + b
# Out:
# 30

# %% [markdown]
# juprer notebook 마크다운 문법

# %% [markdown]
# # 제목1

# %% [markdown]
# # 문단 & 줄바꿈

# %% [markdown]
# 문단

# %% [markdown]
# 이것은 첫 번째 문단이다. 이것은 두 번째 문단이다.

# %% [markdown]
# 이것은 첫 번째 문단이다.
#
# 이것은 두 번째 문단이다.

# %% [markdown]
# # 강조

# %% [markdown]
# # 목록

# %% [markdown]
# ## 순서 없는 목록 -, *

# %% [markdown]
# - 사과
# - 바나나
# - 포도

# %% [markdown]
# ## 순서 있는 목록

# %% [markdown]
# 1. 데이터 수집
# 2. 데이터 전처리
# 3. 모델 학습
# 4. 결과 분석

# %% [markdown]
# ## 이미지 넣기
#
# * \!\[이미지 예시\](https://cdn.dailyvet.co.kr/wp-content/uploads/2024/05/15231647/20240515ceva_experts4.jpg)

# %% [markdown]
# | 이름 | 나이 | 전공 |
# |---|---|---|
# | 철수 | 20 | 컴퓨터 |
# | 영희 | 21 | 수학 |

# %% [markdown]
# | 이름 | 나이 | 전공 |
# |:---|:---:|---:|
# | 철수 | 20 | 컴퓨터 |
# | 영희 | 21 | 수학 |

# %% [markdown]
# - [x] 데이터 수집
# - [ ] 전처리
# - [ ] 모델 학습

# %% [markdown]
# $y = ax + b$

# %% [markdown]
# $$
# \sum_{i=1}^{n} x_i
# $$
