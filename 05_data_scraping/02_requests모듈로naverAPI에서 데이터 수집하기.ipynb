# %% [markdown]
# # 1. requests 모듈 설치
# * 설명서 링크 [바로가기](https://requests.readthedocs.io/en/latest/)

# %%
# !pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl.metadata (38 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from requests) (3.11)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl (107 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
# Installing collected packages: urllib3, charset_normalizer, certifi, requests
#
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------- ----------------------------- 1/4 [charset_normalizer]
#    ---------- ----------------------------- 1/4 [charset_normalizer]
#    ------------------------------ --------- 3/4 [requests]
#    ------------------------------ --------- 3/4 [requests]
#    ---------------------------------------- 4/4 [requests]
#
# Successfully installed certifi-2026.1.4 charset_normalizer-3.4.4 requests-2.32.5 urllib3-2.6.3

# %% [markdown]
# # 2. requests 사용법
# ```python
# import requests
#
# url = "접속주소url" # url
# payload = dict(key=value) # parameter
# headers = dict(key=value) # headers
# r = requests.get(url.params=payload) # 서버에 url + parameter로 요청보내기 # r은 관용적으로 사용하는 것
# print(r.url) # 서버에 요청을 보낸 url 출력
# print(r.status_code) #서버에서 보내준 응답코드 200 정상, 400, 500은 오류
# response = r.text # r.content, r.json()
# ```
#
# * r.text: utf-8로 인코딩해서 보여줌 한글이 잘 보임
# * r.content:서버가 보내준 그대로의 자료     => 나중에 HTML의 자료를 뽑을 때 사용
# * r.json():requests 모듈 내부의 json모듈로 text를 json으로 자동 변환

# %% [markdown]
# # 3. requests로 네이버 API에서 자료 수집하기

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import requests
import pandas as pd
from myfunc import text_clean

# %% [markdown]
# * 이전 코드

# %%
# 네이버 검색 API 예제 - 블로그 검색
# import os
# import sys
# import urllib.request
# client_id = os.getenv('Client_ID')
# client_secret = os.getenv('Client_secret')
# encText = urllib.parse.quote("삼성전자")
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
# request = urllib.request.Request(url)
# request.add_header("X-Naver-Client-Id",client_id)
# request.add_header("X-Naver-Client-Secret",client_secret)
# response = urllib.request.urlopen(request)
# rescode = response.getcode()
# if(rescode==200):
#     response_body = response.read()
#     print(response_body.decode('utf-8'))
# else:
#     print("Error Code:" + rescode)

# %% [markdown]
# * 새로운 코드(requests를 사용)

# %%
keyword = '삼성전자'
url = "https://openapi.naver.com/v1/search/blog"
payload = dict(query=keyword, display=100,start=1,sort='sim')
headers = {"X-Naver-Client-Id" : os.getenv('Client_ID'),
           "X-Naver-Client-Secret":os.getenv('Client_secret')}

r = requests.get(url, params=payload, headers=headers)
print(r.url) # 옵션(url이 잘 만들어 졌는지 확인하는 용도) 
print(r.status_code) # url과 status_code는 처음에 꼭 찍어보고, 결과가 제대로 오는지 확인이 필요하다.
data = r.text # r.json으로 받으면 바로 딕셔너리로 받을 수 있다.
data
# Out:
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# '{\n\t"lastBuildDate":"Tue, 20 Jan 2026 15:32:03 +0900",\n\t"total":4150504,\n\t"start":1,\n\t"display":100,\n\t"items":[\n\t\t{\n\t\t\t"title":"[\'26 CES 1일차] 윈호텔 <b>삼성전자<\\/b> 단독 전시 후기",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/yellowsoap\\/224152380712",\n\t\t\t"description":"오늘은 2026 CES 1일차 이야기로 윈호텔(Wynn Hotel)에서 열린 <b>삼성전자<\\/b> 전시회 관람을 이야기 해볼까... 입구장 앞에 많은 사람들이 있어 삼성의 인기를 실감할 수 있었습니다. 한쪽에 AI 프로모터가 있었는데... ",\n\t\t\t"bloggername":"세상의 모든 스토리! 우기도령",\n\t\t\t"bloggerlink":"blog.naver.com\\/yellowsoap",\n\t\t\t"postdate":"20260120"\n\t\t},\n\t\t{\n\t\t\t"title":"외국인들 <b>삼성전자<\\/b> 팔고 셀트리온 산다는데",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\
\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/horizon37\\/224147907932",\n\t\t\t"description":"<b>삼성전자<\\/b> 주가가 하늘 모르고 치솟고 있습니다. 커뮤니티에선 &quot;코스피 5천가니까 <b>삼성전자<\\/b>는 15만원가는게 정답&quot; 이라는데 여러분들은 어떻게 생각하시나요? 많은 분들한테 <b>삼성전자<\\/b>는 거의 종교 수준인데요... ",\n\t\t\t"bloggername":"직장인 쩡이의 고군분투 재테크",\n\t\t\t"bloggerlink":"blog.naver.com\\/horizon37",\n\t\t\t"postdate":"20260115"\n\t\t},\n\t\t{\n\t\t\t"title":"<b>삼성전자<\\/b> 주가 전망, 보조지표는 어떤 신호를 보내고 있을까?",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/kis6574\\/224151578822",\n\t\t\t"description":"차트보는 말희아빠 불과 1년 전까지만 해도 5만 원이였던 <b>삼성전자<\\/b> 주가, 심지어 더 떨어질 거라고 전망하는 사람이 훨씬 많았었죠. 하지만 현재 15만 전자 코 앞까지 왔고(200% 가까이 상승), 20만 전자를... ",\n\t\t\t"bloggername":"차트보는 말희아빠",\n\t\t\t"bloggerlink":"blog.naver.com\\/kis6574",\n\t\t\t"postdate":"20260119"\n\t\t},\n\t\t{\n\t\t\t"title":"효성중공업 주가 전망, <b>삼성전자<\\/b> 이후 300만원 주식 등장?",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/blueshw\\/224143423781",\n\t\t\t"description":"<b>삼성전자<\\/b> 이후 300만원 주식 등장? 현재 상장사 중 1주당 가장 비싼 주식은 효성중공업이다. 과거 <b>삼성전자<\\/b>가 액면분할 전 기록했던 황제주 자리를 효성중공업이 이어받을 가능성이 높아졌다. 200만원을... ",\n\t\t\t"bloggername":"보노의 투자 생존기",\n\t\t\t"bloggerlink":"blog.naver.com\\/blueshw",\n\t\t\t"postdate":"20260112"\n\t\t},\n\t\t{\n\t\t\t"title":"&quot;<b>삼성전자<\\/b> 주가 20만원 간다&quot; 평단 13만원 친구의 소름 돋는... ",\n\t\t\t"link":"http ...

# %%
keyword = '삼성전자'
url = "https://openapi.naver.com/v1/search/blog"
payload = dict(query=keyword, display=100,start=1,sort='sim')
headers = {"X-Naver-Client-Id" : os.getenv('Client_ID'),
           "X-Naver-Client-Secret":os.getenv('Client_secret')}

r = requests.get(url, params=payload, headers=headers)
print(r.url) # 옵션(url이 잘 만들어 졌는지 확인하는 용도)
print(r.status_code)
data = r.json()

result = {}
for item in data['items']:
    for key,value in item.items():
        if key in ('title', 'description'):
            value = text_clean(value)
        result.setdefault(key, []).append(value)
        
df = pd.DataFrame(result)
df
# Out:
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
#                                  title  \
# 0             CES 일차 윈호텔 삼성전자 단독 전시 후기
# 1               외국인들 삼성전자 팔고 셀트리온 산다는데
# 2   홍라희 여사 삼성전자 주식 대량 매도 주가에 악재일까 기회일까
# 3             물린 사람이 없는 삼성전자주가 0 년 전망은
# 4     삼성전자 주식 조원 규모 매도하는 이유는 상속세 및 대출금
# ..                                 ...
# 95           HBM 공급망 지도 좋음 삼성전자 SK하이닉스
# 96                 삼성전자 분기 영업이익 0조원 기록
# 97     삼성전자 밸류가 낮아서 업사이드도 높다 HBM 좋은 평가
# 98          삼성전자 주가 오르자 삼성전자우 도 0만원 돌파
# 99      삼성전자 덕에 앉아서 돈 번다 삼성생명 신고가 지속될뜻
#
#                                                  link  \
# 0      https://blog.naver.com/yellowsoap/224152380712
# 1      https://blog.naver.com/yahoyaho08/224145850607
# 2      https://blog.naver.com/totoro3123/224151135821
# 3   https://blog.naver.com/goodbye202407/224138808514
# 4          https://blog.naver.com/lmj400/224151180213
# ..                                                ...
# 95  https://blog.naver.com/going_tothe_moon/224138...
# 96       https://blog.naver.com/pokara61/224139368098
# 97       https://blog.naver.com/pokara61/224119442972
# 98     https://blog.naver.com/tearhunter/224134910389
# 99   https://blog.naver.com/gamemoney572/224153136359
#
#                                           description       bloggername  \
# 0   오늘은 0 CES 일차 이야기로 윈호텔 Wynn Hotel 에서 열린 삼성전자 전시...  세상의 모든 스토리! 우기도령
# 1   외국인들은 어떤 종목을 매수하고 있고 우리도 삼성전자 팔고 외국인들이 사는 종목을 ...     디노의 경제 재테크이야기
# 2   반면 소식을 접하고 의견들을 찾아보니 이번 매각을 삼성전자가 더 높이 날아오르기 위...       너부리의 주식경제노트
# 3   0 년을 지나오며 삼성전자 주가를 두고 이런 말이 나옵니다 이 주식 물린 사람이 거...         여행가는 망고주스
# 4   여러분은 이번 삼성가의 결정을 보며 어떤 생각이 드셨나요 상속세 제도에 대한 견해나...             웰커넥티드
# ..                                                ...               ...
# 95  기업 SK하이닉스 삼성전자 마이크론 ASIC 설계자 ASIC Designer 특정 ...             고잉투더문
# 96  삼성전자 분기 실적이 발표되었다 분기영업이익 0조 달성으로 컨센서스 부합 삼성전자 ...         포카라의 실전투자
# 97  삼성전자가 내년에는 HBM 시장에서 돌파구를 마련할 것인가 삼성전자의 HBM 가 엔...         포카라의 실전투자
# 98  삼성전자 강세 속 삼선전자우도 꾸준히 상승 삼성전자우 우선주 가 월 일 장중 0만원...  웹진 [Coin Choice]
# 99  삼성전자 주가와 동행하는 자산 가치의 재발견 삼성생명은 삼성전자의 최대 주주 중 하...           이슈 와 투자
#
#                         bloggerlink  postdate
# 0         blog.naver.com/yellowsoap  20260120
# 1         blog.naver.com/yahoyaho08  20260114
# 2         blog.naver.com/totoro3123  20260118
# 3      blog.naver.com/goodbye202407  20260109
# 4             blog.naver.com/lmj400  20260118
# ..                              ...       ...
# 95  blog.naver.com/going_tothe_moon  20260108
# 96          blog.naver.com/pokara61  20260108
# 97          blog.naver.com/pokara61  20251223
# 98        blog.naver.com/tearhunter  20260105
# 99      blog.naver.com/gamemoney572  20260120
#
# [100 rows x 6 columns]

# %%
for item in data['items']:
    print(item)
# Out:
# {'title': "['26 CES 1일차] 윈호텔 <b>삼성전자</b> 단독 전시 후기", 'link': 'https://blog.naver.com/yellowsoap/224152380712', 'description': '오늘은 2026 CES 1일차 이야기로 윈호텔(Wynn Hotel)에서 열린 <b>삼성전자</b> 전시회 관람을 이야기 해볼까... 입구장 앞에 많은 사람들이 있어 삼성의 인기를 실감할 수 있었습니다. 한쪽에 AI 프로모터가 있었는데... ', 'bloggername': '세상의 모든 스토리! 우기도령', 'bloggerlink': 'blog.naver.com/yellowsoap', 'postdate': '20260120'}
# {'title': '[CES2026] <b>삼성전자</b> The First Look 2026 전시 관람 후기... ', 'link': 'https://blog.naver.com/star7sss/224151018335', 'description': '여기까지 CES2026 <b>삼성전자</b> 전시 후기였습니다. 전시를 보고 맨 처음 든 생각은... &quot;진짜로 15만 전자 가나&quot;였는데... 전시관람일 1월 8일 라고 생각했을 때 샀어야... ㅋㅋ 그만큼 삼성의 저력을 잘 보여준... ', 'bloggername': 'star가 되기위해', 'bloggerlink': 'blog.naver.com/star7sss', 'postdate': '20260118'}
# {'title': '메모리 반도체 ETF 추천, 대장주 SK하이닉스·<b>삼성전자</b> 함께... ', 'link': 'https://blog.naver.com/hojin4231/224152137915', 'description': '출처:삼성 Kodex etf 홈페이지 메모리 쇼티지 국면에서 가장 기본적인 선택지는 KODEX 반도체입니다. <b>삼성전자</b>와 SK하이닉스를 중심으로 국내 반도체 전반을 담고 있어, 특정 기술에 치우치지 않고 업황 회복... ', 'bloggername': '금성인의 지구 정복', 'bloggerlink': 'blog.naver.com/hojin4231', 'postdate': '20260120'}
# {'title': '<b>삼성전자</b> 주가 전망과 목표 주가', 'link': 'https://blog.naver.com/tomtomhm/224149388866', 'description': '③ 스마트폰·가전 업황 <b>삼성전자</b>의 모바일과 소비자 전자제품 부문은 성숙 시장이기 때문에 성장 속도가 빠른 반도체 부문보다는 느린 편이라는 지적도 있습니다. 5. 요약: 투자 관점에서 본 <b>삼성전자</b>... ', 'bloggername': 'Mr 잡다구리', 'bloggerlink': 'blog.naver.com/tomtomhm', 'postdate': '20260116'}
# {'title': '<b>삼성전자</b> 주가 무려 7% 급등, 20만전자 가능할까', 'link': 'https://blog.naver.com/isshoko/224131791497', 'description': '<b>삼성전자</b> 20만전자 되려면 필요한 조건은? 만약 <b>삼성전자</b> 주가가 20만 원까지 가려면 단순한 호황을 넘어 다음과 같은 구조적 변화가 필수적입니다. 파운드리 사업의 구조적 흑자 전환 HBM 시장에서... ', 'bloggername': '한녕, 경제로그', 'bloggerlink': 'blog.naver.com/isshoko', 'postdate': '20260102'}
# {'title': '<b>삼성전자</b>, 130인치 크기의 마이크로 RGB TV 공개', 'link': 'https://blog.naver.com/mobano/224135132335', 'description': '정보 및 사진 출처 삼성 뉴스룸 / 홈페이지 <b>삼성전자</b>, 130인치 크기의 마이크로 RGB TV 공개 목차 1. 디스플레이: 100㎛ 이하 칩셋과 RGB 제어 2. 디자인: 타임리스 프레임 3. 화질 엔진 및 인증: AI 프로세서... ', 'bloggername': '모바노', 'bloggerlink': 'blog.naver.com/mobano', 'postdate': '20260105'}
# {'title': '<b>삼성전자</b> 주가 7% 급등 상승 이유 팔아야되나', 'link': 'https://blog.naver.com/loveisimpress/224134069481', 'description': "<b>삼성전자</b> 주가 7% 급등 이유 1.전영현 부회장의 신년사 : '기술의 삼성' 부활 신호탄 이번 급등의... '10만전자'를 넘어 '16만전자'까지 갈 수 있다는 기대감이 개미들의 투심을 자극했습니다. 3. 맺음말... ", 'bloggername': '경제 IT로거', 'bloggerlink': 'blog.naver.com/loveisimpress', 'postdate': '20260105'}
# {'title': 'HBM 공급망 지도 좋음 (<b>삼성전자</b>, SK하이닉스)', 'link': 'https://blog.naver.com/going_tothe_moon/224138531079', 'description': '기업 -SK하이닉스, <b>삼성전자</b>, 마이크론 2) ASIC 설계자 (ASIC Designer): 특정 목적(AI 연산 등)에 최적화된... SK하이닉스, <b>삼성전자</b>, 마이크론의 매출이 함께 늘어나는 구조 * 빅테크들이 엔비디아 의존도를... ', 'bloggername': '고잉투더문', 'bloggerlink': 'blog.naver.com/going_tothe_moon', 'postdate': '20260108'}
# {'title': '<b>삼성전자</b> : 4분기 영업이익 20조원 기록', 'link': 'https://blog.naver.com/pokara61/224139368098', 'description': '<b>삼성전자</b> 4분기 실적이 발표되었다. 분기영업이익 20조 달성으로 컨센서스 부합... <b>삼성전자</b> 메모리 실적의 업종 내 열위 국면 해소 시작 전망. AI 수요 강세와 더불어 AI 컴퓨팅 파워 제고의... ', 'bloggername': '포카라의 실전투자', 'bloggerlink': 'blog.naver.com/pokara61', 'postdate': '20260108'}
# {'title': '<b>삼성전자</b> : 밸류가 낮아서 업사이드도 높다. HBM4 좋은 평가... ', 'link': 'https://blog.naver.com/pokara61/224119442972', 'description': '<b>삼성전자</b>가 내년에는 HBM4 시장에서 돌파구를 마련할 것인가? <b>삼성전자</b>의 HBM4가 엔비디아 테스트에서 최고 평가를 획득함에 따라 2025년 상반기 공급망 진입 가능성이 높아졌다. 디램에서는... ', 'bloggername': '포카라의 실전투자', 'bloggerlink': 'blog.naver.com/pokara61', 'postdate': '20251223'}
# {'title': "<b>삼성전자</b> 주가 오르자 '<b>삼성전자</b>우'도 10만원 돌파", 'link': 'https://blog.naver.com/tearhunter/224134910389', 'description': "<b>삼성전자</b> 강세 속 삼선전자우도 꾸준히 상승 <b>삼성전자</b>우(우선주)가 1월 5일 장중 10만원을 돌파하며 '10만전자우' 시대를 열었다. 수년간 박스권에 갇혀 있던 주가가 사상 최고가 영역으로 진입하면서, 그간... ", 'bloggername': '웹진 [Coin Choice]', 'bloggerlink': 'blog.naver.com/tearhunter', 'postdate': '20260105'}
# {'title': '<b>삼성전자</b> 덕에 앉아서 돈 번다? 삼성생명  신고가 지속될뜻.', 'link': 'https://blog.naver.com/gamemoney572/224153136359', 'description': "<b>삼성전자</b> 주가와 동행하는 '자산 가치의 재발견' 삼성생명은 <b>삼성전자</b>의 최대 주주 중 하나로, 약 8.5%의 지분을 보유하고 있습니다. 최근 <b>삼성전자</b>의 주가 랠리는 곧 삼성생명이 가진 장부상 자산 가치의... ", 'bloggername': '이슈 와 투자', 'bloggerlink': 'blog.naver.com/gamemoney572', 'postdate': '20260120'}

# %%
result = {}
for item in data['items']:
    for key,value in item.items():
        if key in ('title', 'description'):
            value = text_clean(value)
        result.setdefault(key, []).append(value)
        
df = pd.DataFrame(result)
df
# Out:
#                                  title  \
# 0             CES 일차 윈호텔 삼성전자 단독 전시 후기
# 1               외국인들 삼성전자 팔고 셀트리온 산다는데
# %%
import os
import requests
import pandas as pd
from myfunc import text_clean
from dotenv import load_dotenv
load_dotenv() # 가장 아래에 두면 true가 출력되기 때문에 좋다.
# Out:
# True

# %% [markdown]
# * urllib를 사용해서 1100개 가져오는 코드

# %%
# result = {} # ! result 이동/ for문 안쪽에 있으면 계속 초기화 된다.


# for num in range(1, 1101, 100):
#     print(num)
#     if num > 1000:
#         num -= 1

#     # 네이버 검색 API 예제 - 블로그 검색
#     client_id = os.getenv('Client_ID')
#     client_secret = os.getenv('Client_secret')
#     encText = urllib.parse.quote("삼성전자")
#     parameters = f"&display=100&start={num}&sort=sim" # ! f-string 추가
#     url = "https://openapi.naver.com/v1/search/blog?query=" + encText + parameters # JSON 결과
#     # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
#     request = urllib.request.Request(url)
#     request.add_header("X-Naver-Client-Id",client_id)
#     request.add_header("X-Naver-Client-Secret",client_secret)
#     response = urllib.request.urlopen(request)
#     rescode = response.getcode()
#     if(rescode==200):
#         response_body = response.read()
#         response = response_body.decode('utf-8') # ! 추가 및 수정
#         data = json.loads(response) # ! 추가 및 수정
#     else:
#         print("Error Code:" + rescode)
    
    

#     for item in data['items']:
#         print(item)
#         for key,value in item.items():
#             if key in ['title', 'description']:
#                 value = text_clean(value)
#             result.setdefault(key, []).append(value) # ! 추가

            
# df = pd.DataFrame(result)
# df

# %% [markdown]
# * requests를 사용해서 1100개 가져오는 코드

# %%
keyword = '삼성전자'
url = "https://openapi.naver.com/v1/search/blog"
payload = dict(query=keyword, display=100,start=1,sort='sim')
headers = {"X-Naver-Client-Id" : os.getenv('Client_ID'),
           "X-Naver-Client-Secret":os.getenv('Client_secret')}

r = requests.get(url, params=payload, headers=headers)
print(r.url) # 옵션(url이 잘 만들어 졌는지 확인하는 용도)
print(r.status_code)
data = r.json()


result = {}
i = 0
while i < len(data['items']):
    item = data['items'][i]
    for key,value in item.items():
        if key in ('title', 'description'):
            vaule = text_clean(value)
        result.setdefault(key, []).append(value)
        
    i += 1
        
df = pd.DataFrame(result)
df
# Out:
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
#                                              title  \
# 0           ['26 CES 1일차] 윈호텔 <b>삼성전자</b> 단독 전시 후기
# 1                    외국인들 <b>삼성전자</b> 팔고 셀트리온 산다는데
# 2      홍라희 여사 <b>삼성전자</b> 주식 대량 매도, 주가에 악재일까 기회일까?
# 3              물린 사람이 없는 <b>삼성전자</b>주가, 2026년 전망은?
# 4        <b>삼성전자</b> 주식 2조원 규모 매도하는 이유는(상속세 및 대출금)
# ..                                             ...
# 95                 <b>삼성전자</b> : 레거시 디램의  왕이 돌아왔다!
# 96             HBM 공급망 지도 좋음 (<b>삼성전자</b>, SK하이닉스)
# 97                  <b>삼성전자</b> : 4분기 영업이익 20조원 기록
# 98  <b>삼성전자</b> : 밸류가 낮아서 업사이드도 높다. HBM4 좋은 평가...
# 99      <b>삼성전자</b> 주가 오르자 '<b>삼성전자</b>우'도 10만원 돌파
#
#                                                  link  \
# 0      https://blog.naver.com/yellowsoap/224152380712
# 1      https://blog.naver.com/yahoyaho08/224145850607
# 2      https://blog.naver.com/totoro3123/224151135821
# 3   https://blog.naver.com/goodbye202407/224138808514
# 4          https://blog.naver.com/lmj400/224151180213
# ..                                                ...
# 95       https://blog.naver.com/pokara61/224134665685
# 96  https://blog.naver.com/going_tothe_moon/224138...
# 97       https://blog.naver.com/pokara61/224139368098
# 98       https://blog.naver.com/pokara61/224119442972
# 99     https://blog.naver.com/tearhunter/224134910389
#
#                                           description       bloggername  \
# 0   오늘은 2026 CES 1일차 이야기로 윈호텔(Wynn Hotel)에서 열린 <b>...  세상의 모든 스토리! 우기도령
# 1   외국인들은 어떤 종목을 매수하고 있고 우리도 <b>삼성전자</b> 팔고 외국인들이 ...     디노의 경제 재테크이야기
# 2   반면, 소식을 접하고 의견들을 찾아보니 이번 매각을 <b>삼성전자</b>가 더 높이...       너부리의 주식경제노트
# 3   2025년을 지나오며 <b>삼성전자</b> 주가를 두고 이런 말이 나옵니다. “이 ...         여행가는 망고주스
# 4   여러분은 이번 삼성가의 결정을 보며 어떤 생각이 드셨나요? 상속세 제도에 대한 견해...             웰커넥티드
# ..                                                ...               ...
# 95  HBM 시장에서 삼성은 선전할 것인가? <b>삼성전자</b>는 HBM 시장에서 올해...         포카라의 실전투자
# 96  기업 -SK하이닉스, <b>삼성전자</b>, 마이크론 2) ASIC 설계자 (ASI...             고잉투더문
# 97  <b>삼성전자</b> 4분기 실적이 발표되었다. 분기영업이익 20조 달성으로 컨센서...         포카라의 실전투자
# 98  <b>삼성전자</b>가 내년에는 HBM4 시장에서 돌파구를 마련할 것인가? <b>삼...         포카라의 실전투자
# 99  <b>삼성전자</b> 강세 속 삼선전자우도 꾸준히 상승 <b>삼성전자</b>우(우선...  웹진 [Coin Choice]
#
#                         bloggerlink  postdate
# 0         blog.naver.com/yellowsoap  20260120
# 1         blog.naver.com/yahoyaho08  20260114
# 2         blog.naver.com/totoro3123  20260118
# 3      blog.naver.com/goodbye202407  20260109
# 4             blog.naver.com/lmj400  20260118
# ..                              ...       ...
# 95          blog.naver.com/pokara61  20260105
# 96  blog.naver.com/going_tothe_moon  20260108
# 97          blog.naver.com/pokara61  20260108
# 98          blog.naver.com/pokara61  20251223
# 99        blog.naver.com/tearhunter  20260105
#
# [100 rows x 6 columns]

# %%
result = {}

while num < 

for num in range(1, 1101, 100):
    print(num)
    if num > 1000:
        num -= 1
while 
i = 0
i < 1101
i += 100
        
        
    keyword = '삼성전자'
    url = "https://openapi.naver.com/v1/search/blog"
    payload = dict(query=keyword, display=100,start=1,sort='sim')
    headers = {"X-Naver-Client-Id" : os.getenv('Client_ID'),
               "X-Naver-Client-Secret":os.getenv('Client_secret')}

    r = requests.get(url, params=payload, headers=headers)
    print(r.url) # 옵션(url이 잘 만들어 졌는지 확인하는 용도)
    print(r.status_code)
    data = r.json()

#     result = {}
    i = 0
    while i < len(data['items']):
        item = data['items'][i]
        for key,value in item.items():
            if key in ('title', 'description'):
                vaule = text_clean(value)
            result.setdefault(key, []).append(value)

        i += 1
        
df = pd.DataFrame(result)
df
# Out:
# 1
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 101
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 201
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 301
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 401
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 501
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 601
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 701
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 801
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 901
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# 1001
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
#                                                title  \
# 0             ['26 CES 1일차] 윈호텔 <b>삼성전자</b> 단독 전시 후기
# 1                      외국인들 <b>삼성전자</b> 팔고 셀트리온 산다는데
# 2        홍라희 여사 <b>삼성전자</b> 주식 대량 매도, 주가에 악재일까 기회일까?
# 3                물린 사람이 없는 <b>삼성전자</b>주가, 2026년 전망은?
# 4          <b>삼성전자</b> 주식 2조원 규모 매도하는 이유는(상속세 및 대출금)
# ...                                              ...
# 1095                 <b>삼성전자</b> : 레거시 디램의  왕이 돌아왔다!
# 1096             HBM 공급망 지도 좋음 (<b>삼성전자</b>, SK하이닉스)
# 1097                  <b>삼성전자</b> : 4분기 영업이익 20조원 기록
# 1098  <b>삼성전자</b> : 밸류가 낮아서 업사이드도 높다. HBM4 좋은 평가...
# 1099      <b>삼성전자</b> 주가 오르자 '<b>삼성전자</b>우'도 10만원 돌파
#
#                                                    link  \
# 0        https://blog.naver.com/yellowsoap/224152380712
# 1        https://blog.naver.com/yahoyaho08/224145850607
# 2        https://blog.naver.com/totoro3123/224151135821
# 3     https://blog.naver.com/goodbye202407/224138808514
# 4            https://blog.naver.com/lmj400/224151180213
# ...                                                 ...
# 1095       https://blog.naver.com/pokara61/224134665685
# 1096  https://blog.naver.com/going_tothe_moon/224138...
# 1097       https://blog.naver.com/pokara61/224139368098
# 1098       https://blog.naver.com/pokara61/224119442972
# 1099     https://blog.naver.com/tearhunter/224134910389
#
#                                             description       bloggername  \
# 0     오늘은 2026 CES 1일차 이야기로 윈호텔(Wynn Hotel)에서 열린 <b>...  세상의 모든 스토리! 우기도령
# 1     외국인들은 어떤 종목을 매수하고 있고 우리도 <b>삼성전자</b> 팔고 외국인들이 ...     디노의 경제 재테크이야기
# 2     반면, 소식을 접하고 의견들을 찾아보니 이번 매각을 <b>삼성전자</b>가 더 높이...       너부리의 주식경제노트
# 3     2025년을 지나오며 <b>삼성전자</b> 주가를 두고 이런 말이 나옵니다. “이 ...         여행가는 망고주스
# 4     여러분은 이번 삼성가의 결정을 보며 어떤 생각이 드셨나요? 상속세 제도에 대한 견해...             웰커넥티드
# ...                                                 ...               ...
# 1095  HBM 시장에서 삼성은 선전할 것인가? <b>삼성전자</b>는 HBM 시장에서 올해...         포카라의 실전투자
# 1096  기업 -SK하이닉스, <b>삼성전자</b>, 마이크론 2) ASIC 설계자 (ASI...             고잉투더문
# 1097  <b>삼성전자</b> 4분기 실적이 발표되었다. 분기영업이익 20조 달성으로 컨센서...         포카라의 실전투자
# 1098  <b>삼성전자</b>가 내년에는 HBM4 시장에서 돌파구를 마련할 것인가? <b>삼...         포카라의 실전투자
# 1099  <b>삼성전자</b> 강세 속 삼선전자우도 꾸준히 상승 <b>삼성전자</b>우(우선...  웹진 [Coin Choice]
#
#                           bloggerlink  postdate
# 0           blog.naver.com/yellowsoap  20260120
# 1           blog.naver.com/yahoyaho08  20260114
# 2           blog.naver.com/totoro3123  20260118
# 3        blog.naver.com/goodbye202407  20260109
# 4               blog.naver.com/lmj400  20260118
# ...                               ...       ...
# 1095          blog.naver.com/pokara61  20260105
# 1096  blog.naver.com/going_tothe_moon  20260108
# 1097          blog.naver.com/pokara61  20260108
# 1098          blog.naver.com/pokara61  20251223
# 1099        blog.naver.com/tearhunter  20260105
#
# [1100 rows x 6 columns]

# %% [markdown]
# * while문 로직

# %%
start_num = 1
while True:
    
    if start_num == 1001:
        start_num -= 1
    
    if start_num > 1000:
        break
    
    start_num += 100
    print(start_num)
# Out:
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
# 1001
# 1100

# %%
result = {}

start_num = 1
while True:

    
    if start_num == 1001:
        start_num -= 1
    
    elif start_num > 1000:
        break

    print("start_num: ", start_num)     
#     print('start_num: ', start_num, end='\r')
    
    keyword = '삼성전자'
    url = "https://openapi.naver.com/v1/search/blog"
    payload = dict(query=keyword, display=100,start=start_num,sort='sim')
    headers = {"X-Naver-Client-Id":os.getenv('Client_ID'),
               "X-Naver-Client-Secret":os.getenv('Client_Secret')}

    r = requests.get(url, params=payload, headers=headers)
    print(r.url) # 옵션(url이 잘 만들어 졌는지 확인하는 용도)
    print(r.status_code)
    data = r.json()

    for item in data['items']:
        for key,value in item.items():
            if key in ('title', 'description'):
                value = text_clean(value)
            result.setdefault(key, []).append(value)

    start_num += 100 # 숫자 증가는 while문에서 마지막에 추가된다.(다음 페이지로 넘어가야 하니까)
        
df = pd.DataFrame(result)
df
# Out:
# start_num:  1
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1&sort=sim
# 200
# start_num:  101
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=101&sort=sim
# 200
# start_num:  201
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=201&sort=sim
# 200
# start_num:  301
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=301&sort=sim
# 200
# start_num:  401
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=401&sort=sim
# 200
# start_num:  501
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=501&sort=sim
# 200
# start_num:  601
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=601&sort=sim
# 200
# start_num:  701
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=701&sort=sim
# 200
# start_num:  801
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=801&sort=sim
# 200
# start_num:  901
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=901&sort=sim
# 200
# start_num:  1000
# https://openapi.naver.com/v1/search/blog?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&display=100&start=1000&sort=sim
# 200
#                                          title  \
# 0                     CES 일차 윈호텔 삼성전자 단독 전시 후기
# 1                       외국인들 삼성전자 팔고 셀트리온 산다는데
# 2                     물린 사람이 없는 삼성전자주가 0 년 전망은
# 3           홍라희 여사 삼성전자 주식 대량 매도 주가에 악재일까 기회일까
# 4             삼성전자 주식 조원 규모 매도하는 이유는 상속세 및 대출금
# ...                                        ...
# 1095             삼성전자 주식 환율이 이렇게 오르면 이익인가 손해인가
# 1096                       삼성전자 SK하이닉스 오픈AI 협업
# 1097  quot 미국 반도체 관세 00 경고 quot 삼성전자 SK하이닉스 주가
# 1098          삼성 사무용 프린터 복합기 삼성전자 사업자몰에서 할인받는법
# 1099            삼성전자 주식 배당금 기준일 지급일 배당락 세금은 얼마
#
#                                                    link  \
# 0        https://blog.naver.com/yellowsoap/224152380712
# 1        https://blog.naver.com/yahoyaho08/224145850607
# 2     https://blog.naver.com/goodbye202407/224138808514
# 3        https://blog.naver.com/totoro3123/224151135821
# 4            https://blog.naver.com/lmj400/224151180213
# ...                                                 ...
# 1095      https://blog.naver.com/minho2824/224152425935
# 1096   https://blog.naver.com/alexia_story/224030227268
# 1097       https://blog.naver.com/wjdxor54/224150675125
# 1098       https://blog.naver.com/xodud890/224049835317
# 1099   https://blog.naver.com/galanode2372/223909137933
#
#                                             description       bloggername  \
# 0     오늘은 0 CES 일차 이야기로 윈호텔 Wynn Hotel 에서 열린 삼성전자 전시...  세상의 모든 스토리! 우기도령
# 1     외국인들은 어떤 종목을 매수하고 있고 우리도 삼성전자 팔고 외국인들이 사는 종목을 ...     디노의 경제 재테크이야기
# 2     0 년을 지나오며 삼성전자 주가를 두고 이런 말이 나옵니다 이 주식 물린 사람이 거...         여행가는 망고주스
# 3     반면 소식을 접하고 의견들을 찾아보니 이번 매각을 삼성전자가 더 높이 날아오르기 위...       너부리의 주식경제노트
# 4     여러분은 이번 삼성가의 결정을 보며 어떤 생각이 드셨나요 상속세 제도에 대한 견해나...             웰커넥티드
# ...                                                 ...               ...
# 1095  가만히 생각해 보면 단순히 한국에서만 생활할 것이라면 삼성전자 주식이 상당히 오른 ...    자유로운 쿤이네 경제이야기
# 1096  이 자리에는 구매의향서 LOI 체결에 참여한 전영현 삼성전자 부회장 최성안 삼성중공...     알렉시아의 꾸준하게...
# 1097  삼성과 하이닉스 반도체 관세 주가 영향은 우리에게 가장 중요한 건 이번 발언으로 내...       파트라슈의 주식이야기
# 1098  삼성 사무용 프린터 삼성 복합기 삼성전자 사업자몰에서 할인받고 구매하는법 0월 특가...    sienna's story
# 1099  그리고 국내주식 대장은 역시 누구나 알고 있는 삼성전자임 한때 0만전자라고 외칠 정...       돈되는건 다하는 헐크
#
#                        bloggerlink  postdate
# 0        blog.naver.com/yellowsoap  20260120
# 1        blog.naver.com/yahoyaho08  20260114
# 2     blog.naver.com/goodbye202407  20260109
# 3        blog.naver.com/totoro3123  20260118
# 4            blog.naver.com/lmj400  20260118
# ...                            ...       ...
# 1095      blog.naver.com/minho2824  20260119
# 1096   blog.naver.com/alexia_story  20251003
# 1097       blog.naver.com/wjdxor54  20260118
# 1098       blog.naver.com/xodud890  20251022
# 1099   blog.naver.com/galanode2372  20250623
#
# [1100 rows x 6 columns]

# %% [markdown]
# # keyword를 입력받아서 blog, news, book 카테고리에서 데이터 수집 후 결과를 각각 csv 파일로 저장하기
# * naver_api에서 키워드와 관련된 news, blog, book 자료를 1100개씩 검색하고
# * keyword_news_result.csv, keyword_blof_result.csv, keyword_book_result.csv 형태로 저장되도록 하세요.

# %%
keyword = input()
print(keyword)
# Out:
# 핀테크
# 핀테크

# %% [markdown]
# * 실습

# %%
keyword = input()
print(keyword)

total_result = {}

naver_api_category = ['blog', 'news', 'book']
for category in naver_api_category:
    
    result = {}
    start_num = 1
    while True:

        if start_num == 1001:
            start_num -= 1

        elif start_num > 1000:
            break

        print("start_num: ", start_num)     
#     print('start_num: ', start_num, end='\r')

        url = f"https://openapi.naver.com/v1/search/{category}"
        payload = dict(query=keyword, display=100,start=start_num,sort='sim')
        headers = {"X-Naver-Client-Id" : os.getenv('Client_ID'),
                   "X-Naver-Client-Secret":os.getenv('Client_Secret')}

        r = requests.get(url, params=payload, headers=headers)
        print(r.url)
        print(r.status_code)
        data = r.json()

        for item in data['items']:
            for key,value in item.items():
                if key in ('title', 'description'):
                    value = text_clean(value)
                result.setdefault(key, []).append(value)

        start_num += 100
        
df = pd.DataFrame(result)
df
# Out:
# 핀테크
# 핀테크
# start_num:  1
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# start_num:  101
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# start_num:  201
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# start_num:  301
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# start_num:  401
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# start_num:  501
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# start_num:  601
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# start_num:  701
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# start_num:  801
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# start_num:  901
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# start_num:  1000
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# start_num:  1
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# start_num:  101
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# start_num:  201
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# start_num:  301
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# start_num:  401
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# start_num:  501
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# start_num:  601
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# start_num:  701
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# start_num:  801
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# start_num:  901
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# start_num:  1000
# https://openapi.naver.com/v1/search/news?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# start_num:  1
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# start_num:  101
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# start_num:  201
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# start_num:  301
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# start_num:  401
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# start_num:  501
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# start_num:  601
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# start_num:  701
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# start_num:  801
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# start_num:  901
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# start_num:  1000
# https://openapi.naver.com/v1/search/book?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
#                                                  title  \
# 0                                 핀테크 0 핀테크 혁명과 금융의 미래
# 1                                 핀테크 0 핀테크 혁명과 금융의 미래
# 2                                                  핀테크
# 3                               핀테크 IT와 금융이 만나는 새로운 세상
# 4                                           핀테크와 법 제 판
# ..                                                 ...
# 105  전국 체험마을 주소록 0 CD D프린터 IOT VR 가상현실 드론 바이오기업 스마트...
# 106  신남방 지역 주요국의 핀테크 발전과 협력방안 인도 태국 말레이시아 베트남 인도네시아...
# 107  핀테크 블록체인 기술이 적용된 온라인 시스템 전자결제 보안 인증 시장 전망과 핵심기...
# 108   IoT기반 근거리 무선통신 핀테크 산업 현황과 무선전력 전송 및 무선충전 기술개발 동향
# 109  CD 0 차산업 기업 스타트업 주소록 CD ROM 장 가상현실 드론 로봇 빅데이터 ...
#
#                                                   link  \
# 0    https://search.shopping.naver.com/book/catalog...
# 1    https://search.shopping.naver.com/book/catalog...
# 2    https://search.shopping.naver.com/book/catalog...
# 3    https://search.shopping.naver.com/book/catalog...
# 4    https://search.shopping.naver.com/book/catalog...
# ..                                                 ...
# 105  https://search.shopping.naver.com/book/catalog...
# 106  https://search.shopping.naver.com/book/catalog...
# 107  https://search.shopping.naver.com/book/catalog...
# 108  https://search.shopping.naver.com/book/catalog...
# 109  https://search.shopping.naver.com/book/catalog...
#
#                                                  image           author  \
# 0    https://shopping-phinf.pstatic.net/main_564418...              김종현
# 1    https://shopping-phinf.pstatic.net/main_520007...              김종현
# 2    https://shopping-phinf.pstatic.net/main_324383...              한석주
# 3    https://shopping-phinf.pstatic.net/main_325064...              강창호
# 4    https://shopping-phinf.pstatic.net/main_324417...      강현구^유주선^이성남
# ..                                                 ...              ...
# 105  https://shopping-phinf.pstatic.net/main_466775...     한국콘텐츠미디어 편집부
# 106  https://shopping-phinf.pstatic.net/main_332340...  이충열^이종하^이선호^강성범
# 107  https://shopping-phinf.pstatic.net/main_324381...          TF정보분석실
# 108  https://shopping-phinf.pstatic.net/main_324975...          TF정보분석실
# 109  https://shopping-phinf.pstatic.net/main_324666...         한국콘텐츠미디어
#
#     discount  publisher   pubdate           isbn  \
# 0      17480    한국금융연수원  20250826  9788928782796
# 1          0    한국금융연수원  20241216  9788928782284
# 2      11400   커뮤니케이션북스  20151101  9791130441436
# 3          0      한빛미디어  20150605  9788968482007
# 4      19800       씨아이알  20201112  9791156109020
# ..       ...        ...       ...            ...
# 105   215100   한국콘텐츠미디어  20240322  9791172340193
# 106     9500  대외경제정책연구원  20201231  9788932290201
# 107   342000     트렌드포커스  20190429  9791188774074
# 108   279000     트렌드포커스  20150709  9791195558117
# 109   179550   한국콘텐츠미디어  20180921  9791155055663
#
#                                            description
# 0    본서에서는 세계 최초로 핀테크 산업의 발전을 단계로 구분하여 설명하는 핀테크 0 의...
# 1    본서에서는 세계 최초로 핀테크 산업의 발전을 단계로 구분하여 설명하는 핀테크 0 의...
# 2    디지털 기술의 발달은 금융의 모든 것을 바꾸고 있다 기술 기반의 스타트업들과 비금융...
# 3    금융과 기술로 혁신하는 핀테크 시장을 선점하라 상시 연결된 디지털 세상에서 혁신적인...
# 4    핀테크의 영역과 그에 대한 법률문제의 간격을 어떻게 좁힐 수 있을 것인가 핀테크 관...
# ..                                                 ...
# 105  전국 체험마을 주소록을 분야별 지역별로 9건 관광 여가산업 상세정보를 업종별 지역별...
# 106  이 책은 대외경제정책연구원의 신남방 지역 주요국의 핀테크 발전과 협력방안을 다룬 정...
# 107  차 산업혁명 시대에 핀테크와 블록체인이 핵심기술로 떠오르고 있습니다 핀테크는 금융서...
# 108  IoT는 작년에 이어 올해에도 ICT 시장을 뜨겁게 달구는 키워드 중 하나입니다 모...
# 109  0 차산업 기업 스타트업 주소록 CD에는 차 산업기술 바이오헬스케어 창업 스타트업 ...
#
# [110 rows x 9 columns]

# %%
import os
import requests
import pandas as pd
from myfunc import text_clean
from dotenv import load_dotenv
import time
load_dotenv() # 가장 아래에 두면 true가 출력되기 때문에 좋다.
# Out:
# True

# %%
keyword = input('검색할 키워드를 입력하세요: ')

for category in ['blog', 'news', 'book']:
    
    result = {}
    start_num = 1
    while True:

        if start_num == 1001:
            start_num -= 1
        elif start_num > 1000:
            break

        print("start_num: ", start_num)     
#     print('start_num: ', start_num, end='\r')

        url = f"https://openapi.naver.com/v1/search/{category}"
        payload = dict(query=keyword, display=100,start=start_num,sort='sim')
        headers = {"X-Naver-Client-Id" : os.getenv('Client_ID'),
                   "X-Naver-Client-Secret":os.getenv('Client_Secret')}

        r = requests.get(url, params=payload, headers=headers)
#         print(r.url)
#         print(r.status_code)
        data = r.json()

        for item in data['items']:
            for key,value in item.items():
                if key in ('title', 'description'):
                    value = text_clean(value)
                result.setdefault(key, []).append(value)

        start_num += 100
        
    df = pd.DataFrame(result)
    
    dir_name = "data"
    if not os.path.exists(dir_name):
        os.mkdir(dir_name)
        print(f"{dir_name}을 생성했습니다.")
    else:
        print(f"{dir_name}이 이미 있습니다.")
    
    df.to_csv(f'./data/{keyword}_{category}_result.csv')
    
    time.sleep(0.5)
# Out:
# 검색할 키워드를 입력하세요: 스테이블코인
# start_num:  1
# start_num:  101
# start_num:  201
# start_num:  301
# start_num:  401
# start_num:  501
# start_num:  601
# start_num:  701
# start_num:  801
# start_num:  901
# start_num:  1000
# data이 이미 있습니다.
# start_num:  1
# start_num:  101
# start_num:  201
# start_num:  301
# start_num:  401
# start_num:  501
# start_num:  601
# start_num:  701
# start_num:  801
# start_num:  901
# start_num:  1000
# data이 이미 있습니다.
# start_num:  1
# start_num:  101
# start_num:  201
# start_num:  301
# start_num:  401
# start_num:  501
# start_num:  601
# start_num:  701
# start_num:  801
# start_num:  901
# start_num:  1000
# data이 이미 있습니다.

# %% [markdown]
# # naver_api 수집 코드 함수화하기
# * naver_search 함수를 만들고 함수값으로 검색할 키워드를 입력하면
# * naver_api에서 키워드와 관련된 news, blog, book 자료를 1100개씩 검색하고
# * keyword_news_result.csv, keyword_blof_result.csv, keyword_book_result.csv 형태로 저장되도록 하세요.

# %% [markdown]
# * 답안

# %%
import os
import requests
import pandas as pd
from myfunc import text_clean
from dotenv import load_dotenv
import time
load_dotenv() # 가장 아래에 두면 true가 출력되기 때문에 좋다.
# Out:
# True

# %%
def naver_search(keyword):

    for category in ['blog', 'news', 'book']:

        result = {}
        start_num = 1
        while True:

            if start_num == 1001:
                start_num -= 1
            elif start_num > 1000:
                break

            print("start_num: ", start_num)     
#           print('start_num: ', start_num, end='\r')

            url = f"https://openapi.naver.com/v1/search/{category}"
            payload = dict(query=keyword, display=100,start=start_num,sort='sim')
            headers = {"X-Naver-Client-Id" : os.getenv('Client_ID'),
                       "X-Naver-Client-Secret":os.getenv('Client_Secret')}

            r = requests.get(url, params=payload, headers=headers)
    #         print(r.url)
    #         print(r.status_code)
            data = r.json()

            for item in data['items']:
                for key,value in item.items():
                    if key in ('title', 'description'):
                        value = text_clean(value)
                    result.setdefault(key, []).append(value)

            start_num += 100

        df = pd.DataFrame(result)

        dir_name = "data"
        if not os.path.exists(dir_name):
            os.mkdir(dir_name)
            print(f"{dir_name}을 생성했습니다.")
        else:
            print(f"{dir_name}이 이미 있습니다.")

        df.to_csv(f"./data/{keyword}_{category}_result_function.csv", encoding="utf8-sig")

        time.sleep(0.5)

# %%
naver_search("비트코인")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 naver_search("비트코인")
#
# NameError: name 'naver_search' is not defined

# %% [markdown]
# # 키워드와 카테고리를 입력하는대로 검색하고 출력하게 하기

# %%
def naver_search(keyword, *categories): #가변인수로 처리

    for category in categories:

        result = {}
        start_num = 1
        while True:

            if start_num == 1001:
                start_num -= 1
            elif start_num > 1000:
                break

            print("start_num: ", start_num)     
#           print('start_num: ', start_num, end='\r')

            url = f"https://openapi.naver.com/v1/search/{category}"
            payload = dict(query=keyword, display=100,start=start_num,sort='sim')
            headers = {"X-Naver-Client-Id" : os.getenv('Client_ID'),
                       "X-Naver-Client-Secret":os.getenv('Client_Secret')}

            r = requests.get(url, params=payload, headers=headers)
    #         print(r.url)
    #         print(r.status_code)
            data = r.json()

            for item in data['items']:
                for key,value in item.items():
                    if key in ('title', 'description'):
                        value = text_clean(value)
                    result.setdefault(key, []).append(value)

            start_num += 100

        df = pd.DataFrame(result)

        dir_name = "data"
        if not os.path.exists(dir_name):
            os.mkdir(dir_name)
            print(f"{dir_name}을 생성했습니다.")
        else:
            print(f"{dir_name}이 이미 있습니다.")

        df.to_csv(f"./data/{keyword}_{category}_result_function.csv")

        time.sleep(0.5)

# %%
naver_search("삼성전자", 'news', 'blog')
# Out:
# data이 이미 있습니다.:  1000
# data이 이미 있습니다.:  1000
