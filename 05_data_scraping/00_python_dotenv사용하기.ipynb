# %% [markdown]
# # python-dotenv 설치하기
#
# ```python
# pip install python-dotenv
# ```

# %%
# !pip install python-dotenv

# %% [markdown]
# # python-dotenv 사용하기

# %%
import os
from dotenv import load_dotenv

# %%
# .env 파일이 있으면 True, 없으면 False
# .env 파일을 다시 불러올 때는 반드시 kernel을 restart해야 한다.
load_dotenv()
# Out:
# True

# %%
mypw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mypw
#
# NameError: name 'mypw' is not defined

# %%
os.getenv("mypw") # 반드시 os 모델과 같이 사용해야 한다.
# Out:
# '1234'

# %%
mypw = os.getenv("mypw")

# %%
myip = os.getenv("myip")

# %% [markdown]
# # .env 파일 이름이 다르거나 위치가 다른경우
# * load_dotenv('파일경로 및 이름')

# %%
load_dotenv("./.env_copy")
# Out:
# True

# %%
os.getenv("myname")
# Out:
# 'env_copy'

# %%
os.getenv("myip")
# Out:
# '127.0.0.1'

# %% [markdown]
# # .env 경로와 이름이 다른 경우

# %%
load_dotenv("./test_env/.env_copy_copy")
# Out:
# True

# %%
os.getenv("myip")
# Out:
# '127.0.0.3'

# %%
os.getenv('myname')
# Out:
# 'env_copy_copy'
