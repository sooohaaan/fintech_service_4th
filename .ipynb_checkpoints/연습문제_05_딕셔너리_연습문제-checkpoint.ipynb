# %% [markdown]
# ### 문제 1번

# %% [markdown]
# * 1-1

# %%
empty_dict = {}

# %%
empty_dict
# Out:
# {}

# %%
print(empty_dict, type(empty_dict))
# Out:
# {} <class 'dict'>

# %% [markdown]
# * 1-2

# %%
empty_dict2 = dict()

# %%
print(empty_dict2, type(empty_dict))
# Out:
# {} <class 'dict'>

# %% [markdown]
# ### 문제 2번

# %% [markdown]
# * 2-1

# %%
person = {"name": "Alice", "age": 25, "city": "Seoul"}

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %%
print(person, type(person))
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'} <class 'dict'>

# %% [markdown]
# * 2-2

# %%
person2 = dict(name="Alice",age=25,city="Seoul")

# %%
person2
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %%
print(person2, type(person2))
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'} <class 'dict'>

# %% [markdown]
# * 2-3

# %%
person3 = dict([("name", "Alice"),("age",25),("city","Seoul")])

# %%
person3
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %%
print(person, type(person))
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'} <class 'dict'>

# %% [markdown]
# * 2-4

# %%
person4 = dict(zip(["name","age","city"],["Alice",25,"Seoul"]))

# %%
person4
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %%
print(person4, type(person4))
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'} <class 'dict'>

# %% [markdown]
# ### 문제 3번

# %% [markdown]
# * 3-1

# %%
person["name"]
# Out:
# 'Alice'

# %% [markdown]
# * 3-2

# %%
person.get("name", "key 없음")
# Out:
# 'Alice'

# %% [markdown]
# ### 문제 4번

# %% [markdown]
# * 4-1

# %%
person["age"]
# Out:
# 25

# %% [markdown]
# * 4-2

# %%
person.get("age", "key 없음")
# Out:
# 25

# %% [markdown]
# ### 문제 5번

# %% [markdown]
# * 5-1

# %%
person["job"] = "Engineer"

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul', 'job': 'Engineer'}

# %% [markdown]
# * 5-2

# %%
person.setdefault("job","Engineer")
# Out:
# 'Engineer'

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul', 'job': 'Engineer'}

# %% [markdown]
# ### 문제 6번

# %% [markdown]
# * 6-1

# %%
person.update(city="Busan")

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Busan', 'job': 'Engineer'}

# %% [markdown]
# * 6-2

# %%
person["city"] = "Busan"

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Busan', 'job': 'Engineer'}

# %% [markdown]
# ### 문제 7번

# %% [markdown]
# * 7-1

# %%
person.pop("age")
# Out:
# 25

# %%
person
# Out:
# {'name': 'Alice', 'city': 'Busan', 'job': 'Engineer'}

# %% [markdown]
# * "age", 25 추가

# %%
person["age"]=25

# %% [markdown]
# * 7-2

# %%
del person["age"]

# %%
person
# Out:
# {'name': 'Alice', 'city': 'Busan', 'job': 'Engineer'}

# %% [markdown]
# ### 문제 8번

# %% [markdown]
# * 8-1

# %%
person.keys()
# Out:
# dict_keys(['name', 'city', 'job'])

# %% [markdown]
# * 8-2

# %%
for key in person:
    print(key)
# Out:
# name
# city
# job

# %% [markdown]
# ### 문제 9번

# %% [markdown]
# * 9-1

# %%
person.values()
# Out:
# dict_values(['Alice', 'Busan', 'Engineer'])

# %% [markdown]
# * 9-2

# %%
for i in person:
    print(person.get(i,"key 없음"))
# Out:
# Alice
# Busan
# Engineer

# %% [markdown]
# * 9-3

# %%
for val in person.values():
    print(val)
# Out:
# Alice
# Busan
# Engineer

# %% [markdown]
# ### 문제 10번

# %% [markdown]
# * 10-1

# %%
person.items()
# Out:
# dict_items([('name', 'Alice'), ('city', 'Busan'), ('job', 'Engineer')])

# %% [markdown]
# * 10-2

# %%
dict_items = []
for i in person:
    dict_items.append((i, person[i]))
dict_items
# Out:
# [('name', 'Alice'), ('city', 'Busan'), ('job', 'Engineer')]

# %% [markdown]
# ### 문제 11번

# %%
"email" in person
# Out:
# False

# %% [markdown]
# ### 문제 12번

# %% [markdown]
# * 12-1

# %%
person.pop("job")
# Out:
# 'Engineer'

# %%
person
# Out:
# {'name': 'Alice', 'city': 'Busan'}

# %%
person["job"]="Engineer"

# %% [markdown]
# * 12-2

# %%
del person["job"]

# %%
person
# Out:
# {'name': 'Alice', 'city': 'Busan'}

# %% [markdown]
# ### 문제 13번

# %%
person.clear()

# %%
person
# Out:
# {}

# %% [markdown]
# ### 문제 14번

# %%
student = {"name": "Bob", "grades": {"math": 85, "science": 90, "history": 80}}

# %%
student
# Out:
# {'name': 'Bob', 'grades': {'math': 85, 'science': 90, 'history': 80}}

# %% [markdown]
# ### 문제 15번

# %%
print(student["grades"]["science"])
# Out:
# 90

# %% [markdown]
# ### 문제 16번

# %% [markdown]
# * 16-1

# %%
student["grades"]["english"] = "95"

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 85, 'science': 90, 'history': 80, 'english': '95'}}

# %% [markdown]
# * 16-2

# %%
student["grades"] = dict(math=85, science=90, history=80, english=95)

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 85, 'science': 90, 'history': 80, 'english': 95}}

# %% [markdown]
# ### 문제 17번

# %% [markdown]
# * 17-1

# %%
student["math"]= 88

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'history': 80, 'english': 95},
#  'math': 88}

# %% [markdown]
# * 17-2

# %%
student["grades"]["math"] = 88

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'history': 80, 'english': 95},
#  'math': 88}

# %% [markdown]
# * 17-3

# %%
student["grades"] = dict(math=88, science=90, history=80, english=95)

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'history': 80, 'english': 95},
#  'math': 88}

# %% [markdown]
# ### 문제 18번

# %% [markdown]
# * 18-1

# %%
del student["grades"]["history"]

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'english': 95},
#  'math': 88}

# %%
student["history"]=80

# %%
student["grades"]["math"]=88

# %% [markdown]
# * 18-2

# %%
student.pop("history")
# Out:
# 80

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'science': 90, 'english': 95, 'math': 88},
#  'tatal': 273}

# %% [markdown]
# * 18-3

# %% [markdown]
# ### 문제 19번

# %% [markdown]
# * 19-1

# %%
student.setdefault("tatal",sum(student["grades"].values()))
# Out:
# 273

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'science': 90, 'english': 95, 'math': 88},
#  'tatal': 273}

# %%
del student["total"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 del student["total"]
#
# KeyError: 'total'

# %% [markdown]
# * 19-2

# %%
student.setdefault("total", student["grades"]["math"] + student["grades"]["science"] + student["grades"]["english"])
# Out:
# 273

# %%
student
# Out:
# {'name': 'Bob',
#  'grades': {'science': 90, 'english': 95, 'math': 88},
#  'tatal': 273}

# %% [markdown]
# * 19-3

# %% [markdown]
# ### 문제 20번

# %% [markdown]
# ### 문제 21번

# %% [markdown]
# ### 문제 22번

# %% [markdown]
# ### 문제 23번

# %% [markdown]
# ### 문제 24번

# %% [markdown]
# ### 문제 25번

# %% [markdown]
# ### 문제 26번

# %% [markdown]
# ### 문제 27번

# %% [markdown]
# ### 문제 28번

# %% [markdown]
# ### 문제 29번

# %% [markdown]
# ### 문제 30번
