# %% [markdown]
# ### 문제 1

# %% [markdown]
# # 내 첫 번째 노트북

# %% [markdown]
# ### 문제 2

# %% [markdown]
# ## 실습 목표

# %% [markdown]
# ### 문제 3

# %% [markdown]
# 데이터 분석은 질문에서 시작한다.
#
# 좋은 질문이 좋은 결과를 만든다.

# %% [markdown]
# ### 문제 4

# %% [markdown]
# 첫 줄
# 둘째 줄

# %% [markdown]
# ### 문제 5

# %% [markdown]
# **중요**

# %% [markdown]
# ### 문제 6

# %% [markdown]
# *주의*

# %% [markdown]
# ### 문제 7

# %% [markdown]
# ***핵심***

# %% [markdown]
# ### 문제 8

# %% [markdown]
# 변수는 `x = 10`으로 만든다.

# %% [markdown]
# ### 문제 9

# %% [markdown]
# - 사과
# - 바나나
# - 포도

# %% [markdown]
# ### 문제 10

# %% [markdown]
# 1. 수집
# 2. 정제
# 3. 학습

# %% [markdown]
# ### 문제 11

# %% [markdown]
# - 과일
#     - 사과
#     - 바나나

# %% [markdown]
# ### 문제 12

# %% [markdown]
# >측정할 수 없으면 개선할 수 없다.

# %% [markdown]
# ### 문제 13

# %% [markdown]
# ---

# %% [markdown]
# ### 문제 14

# %% [markdown]
# [OpenAI](https://openai.com/)

# %% [markdown]
# ### 문제 15

# %% [markdown]
# ![sample](images/sampl.png)

# %% [markdown]
# ### 문제 16

# %% [markdown]
# |이름|나이|
# |---|---|
# |철수|20|
# |영희|21|

# %% [markdown]
# ### 문제 17

# %% [markdown]
# |L|C|R|
# |:---|:---:|---:|
# |1|2|3|

# %% [markdown]
# ### 문제 18

# %% [markdown]
# - [x] 할일 1
# - [ ] 할일 2
# - [ ] 할일 3

# %% [markdown]
# ### 문제 19

# %% [markdown]
# ```python
# print("hello")
# ```

# %% [markdown]
# ### 문제 20

# %% [markdown]
# ```sql
# SELECT * FROM film LIMIT 5;
# ```

# %% [markdown]
# ### 문제 21

# %% [markdown]
# 직선은 $y = ax + b$ 로 표현한다.

# %% [markdown]
# ### 문제 22

# %% [markdown]
# $$
# \sum_{i=1}^{n} x 1
# $$

# %% [markdown]
# ### 문제 23

# %% [markdown]
# ## 오늘 할 일을
# - 노트북 정리
# - 실습
# - 복습

# %% [markdown]
# ### 문제 24

# %% [markdown]
# **중요한** 것은 꾸준함이다.

# %% [markdown]
# ### 문제 25 ?

# %% [markdown]
# [문서](https://example.com) $READ.md$

# %% [markdown]
# ### 문제 26

# %% [markdown]
# ### 진행상황
# - [x] 데이터 수집
# - [x] 전처리
# - [ ] 모델학습

# %% [markdown]
# ### 문제 27

# %% [markdown]
# |항목|값|
# |:---|:---:|
# |정확도|0.12|
# |손실|0.12|

# %% [markdown]
# ### 문제 28

# %% [markdown]
# # 제목 1: 데이터 분석 보고서
# ## 제목 2: 1. 문제 정의
# (한 줄 설명)
# ## 제목 3: 2. 데이터
# (한 줄 설명)

# %% [markdown]
# ### 문제 29

# %% [markdown]
# 예제 코드
#
# ```python
# nums = [1, 2, 3]
# sum(nums)
# ```

# %% [markdown]
# ### 문제 30

# %% [markdown]
# ## 요약
# > 결과는 재현 가능해야 한다.
# - [x] 데이터 저장
# - [ ] 리포트 작성
# ---
# $$
# 수식 E = mc^2
# $$
